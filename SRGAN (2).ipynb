# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# import zipfile
# import os

# zip_path = '/content/drive/MyDrive/data.zip'
# extract_path = '/content/data'

# with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_path)

# %%
from os import listdir
from os.path import join

from PIL import Image
from torch.utils.data.dataset import Dataset
from torch.utils.data import DataLoader
from torchvision.transforms import Compose, RandomCrop, ToTensor, ToPILImage, CenterCrop, Resize
from torch import nn
from math import log10
from math import exp
import math
import torch.optim as optim
from tqdm import tqdm
import torch
from torchvision.models import vgg19
import torchvision.models as models
import torchvision.utils as utils
import torch.nn.functional as F
from torch.autograd import Variable
import pandas as pd
from torchvision.models import VGG19_Weights

# %%
def gaussian(window_size, sigma):
    gauss = torch.Tensor([exp(-(x - window_size // 2) ** 2 / float(2 * sigma ** 2)) for x in range(window_size)])
    return gauss / gauss.sum()


def create_window(window_size, channel):
    _1D_window = gaussian(window_size, 1.5).unsqueeze(1)
    _2D_window = _1D_window.mm(_1D_window.t()).float().unsqueeze(0).unsqueeze(0)
    window = Variable(_2D_window.expand(channel, 1, window_size, window_size).contiguous())
    return window


def _ssim(img1, img2, window, window_size, channel, size_average=True):
    mu1 = F.conv2d(img1, window, padding=window_size // 2, groups=channel)
    mu2 = F.conv2d(img2, window, padding=window_size // 2, groups=channel)

    mu1_sq = mu1.pow(2)
    mu2_sq = mu2.pow(2)
    mu1_mu2 = mu1 * mu2

    sigma1_sq = F.conv2d(img1 * img1, window, padding=window_size // 2, groups=channel) - mu1_sq
    sigma2_sq = F.conv2d(img2 * img2, window, padding=window_size // 2, groups=channel) - mu2_sq
    sigma12 = F.conv2d(img1 * img2, window, padding=window_size // 2, groups=channel) - mu1_mu2

    C1 = 0.01 ** 2
    C2 = 0.03 ** 2

    ssim_map = ((2 * mu1_mu2 + C1) * (2 * sigma12 + C2)) / ((mu1_sq + mu2_sq + C1) * (sigma1_sq + sigma2_sq + C2))

    if size_average:
        return ssim_map.mean()
    else:
        return ssim_map.mean(1).mean(1).mean(1)


class SSIM(torch.nn.Module):
    def __init__(self, window_size=11, size_average=True):
        super(SSIM, self).__init__()
        self.window_size = window_size
        self.size_average = size_average
        self.channel = 1
        self.window = create_window(window_size, self.channel)

    def forward(self, img1, img2):
        (_, channel, _, _) = img1.size()

        if channel == self.channel and self.window.data.type() == img1.data.type():
            window = self.window
        else:
            window = create_window(self.window_size, channel)

            if img1.is_cuda:
                window = window.cuda(img1.get_device())
            window = window.type_as(img1)

            self.window = window
            self.channel = channel

        return _ssim(img1, img2, window, self.window_size, channel, self.size_average)


def ssim(img1, img2, window_size=11, size_average=True):
    (_, channel, _, _) = img1.size()
    window = create_window(window_size, channel)

    if img1.is_cuda:
        window = window.cuda(img1.get_device())
    window = window.type_as(img1)

    return _ssim(img1, img2, window, window_size, channel, size_average)

# %%
class GeneratorLoss(nn.Module):
    def __init__(self):
        super(GeneratorLoss, self).__init__()
        vgg = vgg19(weights=VGG19_Weights.IMAGENET1K_V1)
        loss_network = nn.Sequential(*list(vgg.features)[:35]).eval()
        for param in loss_network.parameters():
            param.requires_grad = False
        self.loss_network = loss_network
        self.mse_loss = nn.MSELoss()
        self.tv_loss = TVLoss()

    def forward(self, out_labels, out_images, target_images):
        # Adversarial Loss
        adversarial_loss = torch.mean(1 - out_labels)
        # Perception Loss
        perception_loss = self.mse_loss(self.loss_network(out_images), self.loss_network(target_images))
        # Image Loss
        image_loss = self.mse_loss(out_images, target_images)
        # TV Loss
        tv_loss = self.tv_loss(out_images)
        return image_loss + 0.001 * adversarial_loss + 0.006 * perception_loss + 2e-8 * tv_loss


class TVLoss(nn.Module):
    def __init__(self, tv_loss_weight=1):
        super(TVLoss, self).__init__()
        self.tv_loss_weight = tv_loss_weight

    def forward(self, x):
        batch_size = x.size()[0]
        h_x = x.size()[2]
        w_x = x.size()[3]
        count_h = self.tensor_size(x[:, :, 1:, :])
        count_w = self.tensor_size(x[:, :, :, 1:])
        h_tv = torch.pow((x[:, :, 1:, :] - x[:, :, :h_x - 1, :]), 2).sum()
        w_tv = torch.pow((x[:, :, :, 1:] - x[:, :, :, :w_x - 1]), 2).sum()
        return self.tv_loss_weight * 2 * (h_tv / count_h + w_tv / count_w) / batch_size

    @staticmethod
    def tensor_size(t):
        return t.size()[1] * t.size()[2] * t.size()[3]

# %%
class Generator(nn.Module):
    def __init__(self, scale_factor):
        upsample_block_num = int(math.log(scale_factor, 2))

        super(Generator, self).__init__()
        self.block1 = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=9, padding=4),
            nn.PReLU()
        )
        self.block2 = ResidualBlock(64)
        self.block3 = ResidualBlock(64)
        self.block4 = ResidualBlock(64)
        self.block5 = ResidualBlock(64)
        self.block6 = ResidualBlock(64)
        self.block7 = nn.Sequential(
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64)
        )
        block8 = [UpsampleBLock(64, 2) for _ in range(upsample_block_num)]
        block8.append(nn.Conv2d(64, 3, kernel_size=9, padding=4))
        self.block8 = nn.Sequential(*block8)

    def forward(self, x):
        block1 = self.block1(x)
        block2 = self.block2(block1)
        block3 = self.block3(block2)
        block4 = self.block4(block3)
        block5 = self.block5(block4)
        block6 = self.block6(block5)
        block7 = self.block7(block6)
        block8 = self.block8(block1 + block7)

        return (torch.tanh(block8) + 1) / 2


class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.net = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.LeakyReLU(0.2),

            nn.Conv2d(64, 64, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),

            nn.Conv2d(128, 128, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2),

            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),

            nn.Conv2d(256, 256, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2),

            nn.Conv2d(256, 512, kernel_size=3, padding=1),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),

            nn.Conv2d(512, 512, kernel_size=3, stride=2, padding=1),
            nn.BatchNorm2d(512),
            nn.LeakyReLU(0.2),

            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(512, 1024, kernel_size=1),
            nn.LeakyReLU(0.2),
            nn.Conv2d(1024, 1, kernel_size=1)
        )

    def forward(self, x):
        batch_size = x.size(0)
        return torch.sigmoid(self.net(x).view(batch_size))


class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super(ResidualBlock, self).__init__()
        self.conv1 = nn.Conv2d(channels, channels, kernel_size=3, padding=1)
        self.bn1 = nn.BatchNorm2d(channels)
        self.prelu = nn.PReLU()
        self.conv2 = nn.Conv2d(channels, channels, kernel_size=3, padding=1)
        self.bn2 = nn.BatchNorm2d(channels)

    def forward(self, x):
        residual = self.conv1(x)
        residual = self.bn1(residual)
        residual = self.prelu(residual)
        residual = self.conv2(residual)
        residual = self.bn2(residual)

        return x + residual


class UpsampleBLock(nn.Module):
    def __init__(self, in_channels, up_scale):
        super(UpsampleBLock, self).__init__()
        self.conv = nn.Conv2d(in_channels, in_channels * up_scale ** 2, kernel_size=3, padding=1)
        self.pixel_shuffle = nn.PixelShuffle(up_scale)
        self.prelu = nn.PReLU()

    def forward(self, x):
        x = self.conv(x)
        x = self.pixel_shuffle(x)
        x = self.prelu(x)
        return x

# %%
def is_image_file(filename):
    return any(filename.endswith(extension) for extension in ['.png', '.jpg', '.jpeg', '.PNG', '.JPG', '.JPEG'])

def calculate_valid_crop_size(crop_size, upscale_factor):
    return crop_size - (crop_size % upscale_factor)


def train_hr_transform(crop_size):
    return Compose([
        RandomCrop(crop_size),
        ToTensor(),
    ])


def train_lr_transform(crop_size, upscale_factor):
    return Compose([
        ToPILImage(),
        Resize(crop_size // upscale_factor, interpolation=Image.BICUBIC),
        ToTensor()
    ])


def display_transform():
    return Compose([
        ToPILImage(),
        Resize(400),
        CenterCrop(400),
        ToTensor()
    ])

# %%
class TrainDatasetFromFolder(Dataset):
    def __init__(self, dataset_dir, crop_size, upscale_factor):
        super(TrainDatasetFromFolder, self).__init__()
        self.image_filenames = [join(dataset_dir, x) for x in listdir(dataset_dir) if is_image_file(x)]
        crop_size = calculate_valid_crop_size(crop_size, upscale_factor)
        self.hr_transform = train_hr_transform(crop_size)
        self.lr_transform = train_lr_transform(crop_size, upscale_factor)

    def __getitem__(self, index):
        hr_image = self.hr_transform(Image.open(self.image_filenames[index]))
        lr_image = self.lr_transform(hr_image)
        return lr_image, hr_image

    def __len__(self):
        return len(self.image_filenames)

# %%
class ValDatasetFromFolder(Dataset):
    def __init__(self, dataset_dir, upscale_factor):
        super(ValDatasetFromFolder, self).__init__()
        self.upscale_factor = upscale_factor
        self.image_filenames = [join(dataset_dir, x) for x in listdir(dataset_dir) if is_image_file(x)]

    def __getitem__(self, index):
        hr_image = Image.open(self.image_filenames[index])
        w, h = hr_image.size
        crop_size = calculate_valid_crop_size(min(w, h), self.upscale_factor)
        lr_scale = Resize(crop_size // self.upscale_factor, interpolation=Image.BICUBIC)
        hr_scale = Resize(crop_size, interpolation=Image.BICUBIC)
        hr_image = CenterCrop(crop_size)(hr_image)
        lr_image = lr_scale(hr_image)
        hr_restore_img = hr_scale(lr_image)
        return ToTensor()(lr_image), ToTensor()(hr_restore_img), ToTensor()(hr_image)

    def __len__(self):
        return len(self.image_filenames)

# %%
CROP_SIZE = 96         # HR image patch size
UPSCALE_FACTOR = 4
NUM_EPOCHS = 200


train_set = TrainDatasetFromFolder('/content/data/data/DIV2K_train_HR', crop_size=CROP_SIZE, upscale_factor=UPSCALE_FACTOR)
val_set = ValDatasetFromFolder('/content/data/data/DIV2K_valid_HR', upscale_factor=UPSCALE_FACTOR)
train_loader = DataLoader(dataset=train_set, num_workers=2, batch_size=64, shuffle=True)
val_loader = DataLoader(dataset=val_set, num_workers=2, batch_size=1, shuffle=False)

generator_criterion = GeneratorLoss()
netG = Generator(UPSCALE_FACTOR)
netD = Discriminator()

if torch.cuda.is_available():
    netG.cuda()
    netD.cuda()
    generator_criterion.cuda()

optimizerG = optim.Adam(netG.parameters())
optimizerD = optim.Adam(netD.parameters())
# Out:
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100%|██████████| 548M/548M [00:03<00:00, 179MB/s]

# %%
results = {'d_loss': [], 'g_loss': [], 'd_score': [], 'g_score': [], 'psnr': [], 'ssim': []}

for epoch in range(1, NUM_EPOCHS + 1):
    train_bar = tqdm(train_loader)
    running_results = {'batch_sizes': 0, 'd_loss': 0, 'g_loss': 0, 'd_score': 0, 'g_score': 0}

    netG.train()
    netD.train()
    for data, target in train_bar:
        g_update_first = True
        batch_size = data.size(0)
        running_results['batch_sizes'] += batch_size

        real_img = target
        if torch.cuda.is_available():
            real_img = real_img.float().cuda()
        z = data
        if torch.cuda.is_available():
            z = z.float().cuda()
        fake_img = netG(z)
        fake_out = netD(fake_img).mean()
        optimizerG.zero_grad()
        g_loss = generator_criterion(fake_out, fake_img, real_img)
        g_loss.backward()
        optimizerG.step()

        real_out = netD(real_img).mean()
        fake_out = netD(fake_img.detach()).mean()
        d_loss = 1 - real_out + fake_out
        optimizerD.zero_grad()
        d_loss.backward()

        fake_img = netG(z)
        fake_out = netD(fake_img).mean()
        optimizerD.step()

        running_results['g_loss'] += g_loss.item() * batch_size
        running_results['d_loss'] += d_loss.item() * batch_size
        running_results['d_score'] += real_out.item() * batch_size
        running_results['g_score'] += fake_out.item() * batch_size

        train_bar.set_description(desc='[%d/%d] Loss_D: %.4f Loss_G: %.4f D(x): %.4f D(G(z)): %.4f' % (
            epoch, NUM_EPOCHS, running_results['d_loss'] / running_results['batch_sizes'],
            running_results['g_loss'] / running_results['batch_sizes'],
            running_results['d_score'] / running_results['batch_sizes'],
            running_results['g_score'] / running_results['batch_sizes']))

    netG.eval()
    out_path = 'training_results/SRF_' + str(UPSCALE_FACTOR) + '/'
    if not os.path.exists(out_path):
        os.makedirs(out_path)

    with torch.no_grad():
        val_bar = tqdm(val_loader)
        valing_results = {'mse': 0, 'ssims': 0, 'psnr': 0, 'ssim': 0, 'batch_sizes': 0}
        val_images = []
        for val_lr, val_hr_restore, val_hr in val_bar:
            batch_size = val_lr.size(0)
            valing_results['batch_sizes'] += batch_size
            lr = val_lr
            hr = val_hr
            if torch.cuda.is_available():
                lr = lr.float().cuda()
                hr = hr.float().cuda()
            sr = netG(lr)

            batch_mse = ((sr - hr) ** 2).data.mean()
            valing_results['mse'] += batch_mse * batch_size
            batch_ssim = ssim(sr, hr).item()
            valing_results['ssims'] += batch_ssim * batch_size
            valing_results['psnr'] = 10 * log10((hr.max()**2) / (valing_results['mse'] / valing_results['batch_sizes']))
            valing_results['ssim'] = valing_results['ssims'] / valing_results['batch_sizes']
            val_bar.set_description(
                desc='[converting LR images to SR images] PSNR: %.4f dB SSIM: %.4f' % (
                    valing_results['psnr'], valing_results['ssim']))

            val_images.extend(
                [display_transform()(val_hr_restore.squeeze(0)), display_transform()(hr.data.cpu().squeeze(0)),
                 display_transform()(sr.data.cpu().squeeze(0))])
        val_images = torch.stack(val_images)
        val_images = torch.chunk(val_images, val_images.size(0) // 15)
        val_save_bar = tqdm(val_images, desc='[saving training results]')
        index = 1
        for image in val_save_bar:
            image = utils.make_grid(image, nrow=3, padding=5)
            utils.save_image(image, out_path + 'epoch_%d_index_%d.png' % (epoch, index), padding=5)
            index += 1

    out_path = 'epochs/'
    if not os.path.exists(out_path):
        os.makedirs(out_path)

    torch.save(netG.state_dict(), 'epochs/netG_epoch_%d_%d.pth' % (UPSCALE_FACTOR, epoch))
    torch.save(netD.state_dict(), 'epochs/netD_epoch_%d_%d.pth' % (UPSCALE_FACTOR, epoch))

    results['d_loss'].append(running_results['d_loss'] / running_results['batch_sizes'])
    results['g_loss'].append(running_results['g_loss'] / running_results['batch_sizes'])
    results['d_score'].append(running_results['d_score'] / running_results['batch_sizes'])
    results['g_score'].append(running_results['g_score'] / running_results['batch_sizes'])
    results['psnr'].append(valing_results['psnr'])
    results['ssim'].append(valing_results['ssim'])

    if epoch % 10 == 0 and epoch != 0:
        out_path = 'statistics/'
        if not os.path.exists(out_path):
          os.makedirs(out_path)
        data_frame = pd.DataFrame(
            data={'Loss_D': results['d_loss'], 'Loss_G': results['g_loss'], 'Score_D': results['d_score'],
                  'Score_G': results['g_score'], 'PSNR': results['psnr'], 'SSIM': results['ssim']},
            index=range(1, epoch + 1))
        data_frame.to_csv(out_path + 'srf_' + str(UPSCALE_FACTOR) + '_train_results.csv', index_label='Epoch')
# Out:
# [1/200] Loss_D: 0.8275 Loss_G: 0.0609 D(x): 0.5705 D(G(z)): 0.4446: 100%|██████████| 13/13 [01:02<00:00,  4.84s/it]
# [converting LR images to SR images] PSNR: 17.3669 dB SSIM: 0.3409: 100%|██████████| 100/100 [01:00<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [2/200] Loss_D: 0.3735 Loss_G: 0.0388 D(x): 0.7806 D(G(z)): 0.1950: 100%|██████████| 13/13 [01:01<00:00,  4.76s/it]
# [converting LR images to SR images] PSNR: 16.3097 dB SSIM: 0.3462: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:20<00:00,  1.02s/it]
# [3/200] Loss_D: 0.2689 Loss_G: 0.0351 D(x): 0.8649 D(G(z)): 0.1875: 100%|██████████| 13/13 [00:59<00:00,  4.61s/it]
# [converting LR images to SR images] PSNR: 18.9706 dB SSIM: 0.4192: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:20<00:00,  1.01s/it]
# [4/200] Loss_D: 0.5066 Loss_G: 0.0324 D(x): 0.7740 D(G(z)): 0.2903: 100%|██████████| 13/13 [01:00<00:00,  4.63s/it]
# [converting LR images to SR images] PSNR: 18.9612 dB SSIM: 0.4843: 100%|██████████| 100/100 [00:59<00:00,  1.69it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [5/200] Loss_D: 0.2446 Loss_G: 0.0312 D(x): 0.8389 D(G(z)): 0.1594: 100%|██████████| 13/13 [00:59<00:00,  4.58s/it]
# [converting LR images to SR images] PSNR: 18.3109 dB SSIM: 0.4986: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.04it/s]
# [6/200] Loss_D: 0.1306 Loss_G: 0.0288 D(x): 0.8866 D(G(z)): 0.0238: 100%|██████████| 13/13 [00:59<00:00,  4.59s/it]
# [converting LR images to SR images] PSNR: 19.4789 dB SSIM: 0.5481: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.04it/s]
# [7/200] Loss_D: 0.0638 Loss_G: 0.0279 D(x): 0.9828 D(G(z)): 0.1357: 100%|██████████| 13/13 [01:00<00:00,  4.66s/it]
# [converting LR images to SR images] PSNR: 19.7305 dB SSIM: 0.5349: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.05it/s]
# [8/200] Loss_D: 0.9593 Loss_G: 0.0287 D(x): 0.0699 D(G(z)): 0.0690: 100%|██████████| 13/13 [01:00<00:00,  4.67s/it]
# [converting LR images to SR images] PSNR: 20.6097 dB SSIM: 0.5469: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.04it/s]
# [9/200] Loss_D: 1.0000 Loss_G: 0.0277 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.68s/it]
# [converting LR images to SR images] PSNR: 21.0033 dB SSIM: 0.5700: 100%|██████████| 100/100 [00:59<00:00,  1.69it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [10/200] Loss_D: 1.0000 Loss_G: 0.0266 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.57s/it]
# [converting LR images to SR images] PSNR: 20.8433 dB SSIM: 0.5892: 100%|██████████| 100/100 [00:59<00:00,  1.69it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.02it/s]
# [11/200] Loss_D: 1.0000 Loss_G: 0.0254 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.57s/it]
# [converting LR images to SR images] PSNR: 20.9349 dB SSIM: 0.5915: 100%|██████████| 100/100 [00:58<00:00,  1.70it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [12/200] Loss_D: 1.0000 Loss_G: 0.0239 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.57s/it]
# [converting LR images to SR images] PSNR: 21.4037 dB SSIM: 0.5999: 100%|██████████| 100/100 [00:58<00:00,  1.70it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [13/200] Loss_D: 1.0000 Loss_G: 0.0233 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.54s/it]
# [converting LR images to SR images] PSNR: 22.0999 dB SSIM: 0.6328: 100%|██████████| 100/100 [00:59<00:00,  1.69it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.06it/s]
# [14/200] Loss_D: 1.0000 Loss_G: 0.0217 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.61s/it]
# [converting LR images to SR images] PSNR: 22.0613 dB SSIM: 0.6416: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [15/200] Loss_D: 1.0000 Loss_G: 0.0218 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.57s/it]
# [converting LR images to SR images] PSNR: 22.2583 dB SSIM: 0.6507: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [16/200] Loss_D: 1.0000 Loss_G: 0.0203 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.61s/it]
# [converting LR images to SR images] PSNR: 21.7071 dB SSIM: 0.6460: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [17/200] Loss_D: 1.0000 Loss_G: 0.0199 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.57s/it]
# [converting LR images to SR images] PSNR: 20.3761 dB SSIM: 0.6531: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.08it/s]
# [18/200] Loss_D: 1.0000 Loss_G: 0.0199 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.64s/it]
# [converting LR images to SR images] PSNR: 22.0220 dB SSIM: 0.6558: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [19/200] Loss_D: 1.0000 Loss_G: 0.0202 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.67s/it]
# [converting LR images to SR images] PSNR: 21.6230 dB SSIM: 0.6477: 100%|██████████| 100/100 [00:59<00:00,  1.69it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.10it/s]
# [20/200] Loss_D: 1.0000 Loss_G: 0.0199 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.71s/it]
# [converting LR images to SR images] PSNR: 22.9107 dB SSIM: 0.6755: 100%|██████████| 100/100 [00:59<00:00,  1.69it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.08it/s]
# [21/200] Loss_D: 1.0000 Loss_G: 0.0179 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.63s/it]
# [converting LR images to SR images] PSNR: 22.2211 dB SSIM: 0.6741: 100%|██████████| 100/100 [00:59<00:00,  1.69it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.05it/s]
# [22/200] Loss_D: 1.0000 Loss_G: 0.0181 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.60s/it]
# [converting LR images to SR images] PSNR: 23.0957 dB SSIM: 0.6776: 100%|██████████| 100/100 [00:59<00:00,  1.69it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.04it/s]
# [23/200] Loss_D: 1.0000 Loss_G: 0.0181 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.59s/it]
# [converting LR images to SR images] PSNR: 22.0507 dB SSIM: 0.6873: 100%|██████████| 100/100 [00:58<00:00,  1.70it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.04it/s]
# [24/200] Loss_D: 1.0000 Loss_G: 0.0182 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.56s/it]
# [converting LR images to SR images] PSNR: 22.8460 dB SSIM: 0.6890: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [25/200] Loss_D: 1.0000 Loss_G: 0.0181 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.63s/it]
# [converting LR images to SR images] PSNR: 23.5142 dB SSIM: 0.6923: 100%|██████████| 100/100 [00:59<00:00,  1.69it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [26/200] Loss_D: 1.0000 Loss_G: 0.0180 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.60s/it]
# [converting LR images to SR images] PSNR: 22.9192 dB SSIM: 0.6870: 100%|██████████| 100/100 [00:59<00:00,  1.69it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [27/200] Loss_D: 1.0000 Loss_G: 0.0167 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.57s/it]
# [converting LR images to SR images] PSNR: 23.6411 dB SSIM: 0.6998: 100%|██████████| 100/100 [00:59<00:00,  1.69it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [28/200] Loss_D: 1.0000 Loss_G: 0.0166 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.59s/it]
# [converting LR images to SR images] PSNR: 23.3119 dB SSIM: 0.6956: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.05it/s]
# [29/200] Loss_D: 1.0000 Loss_G: 0.0158 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.63s/it]
# [converting LR images to SR images] PSNR: 21.9305 dB SSIM: 0.6807: 100%|██████████| 100/100 [00:59<00:00,  1.69it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.09it/s]
# [30/200] Loss_D: 1.0000 Loss_G: 0.0169 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.61s/it]
# [converting LR images to SR images] PSNR: 23.5204 dB SSIM: 0.7037: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [31/200] Loss_D: 1.0000 Loss_G: 0.0163 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.60s/it]
# [converting LR images to SR images] PSNR: 22.4825 dB SSIM: 0.7007: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.08it/s]
# [32/200] Loss_D: 1.0000 Loss_G: 0.0165 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.57s/it]
# [converting LR images to SR images] PSNR: 22.8749 dB SSIM: 0.6896: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.08it/s]
# [33/200] Loss_D: 1.0000 Loss_G: 0.0163 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.59s/it]
# [converting LR images to SR images] PSNR: 22.5560 dB SSIM: 0.6977: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [34/200] Loss_D: 1.0000 Loss_G: 0.0159 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.61s/it]
# [converting LR images to SR images] PSNR: 22.6529 dB SSIM: 0.7044: 100%|██████████| 100/100 [01:02<00:00,  1.59it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.00it/s]
# [35/200] Loss_D: 1.0000 Loss_G: 0.0163 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:06<00:00,  5.14s/it]
# [converting LR images to SR images] PSNR: 22.5159 dB SSIM: 0.6937: 100%|██████████| 100/100 [01:01<00:00,  1.62it/s]
# [saving training results]: 100%|██████████| 20/20 [00:20<00:00,  1.04s/it]
# [36/200] Loss_D: 1.0000 Loss_G: 0.0167 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:02<00:00,  4.82s/it]
# [converting LR images to SR images] PSNR: 21.1391 dB SSIM: 0.6858: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.01it/s]
# [37/200] Loss_D: 1.0000 Loss_G: 0.0158 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:05<00:00,  5.03s/it]
# [converting LR images to SR images] PSNR: 21.6879 dB SSIM: 0.7045: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.04it/s]
# [38/200] Loss_D: 1.0000 Loss_G: 0.0171 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:02<00:00,  4.82s/it]
# [converting LR images to SR images] PSNR: 21.6061 dB SSIM: 0.6974: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.00it/s]
# [39/200] Loss_D: 1.0000 Loss_G: 0.0165 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:02<00:00,  4.81s/it]
# [converting LR images to SR images] PSNR: 22.6848 dB SSIM: 0.6981: 100%|██████████| 100/100 [01:01<00:00,  1.63it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.05it/s]
# [40/200] Loss_D: 1.0000 Loss_G: 0.0159 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.73s/it]
# [converting LR images to SR images] PSNR: 23.1000 dB SSIM: 0.7023: 100%|██████████| 100/100 [01:01<00:00,  1.63it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.05it/s]
# [41/200] Loss_D: 1.0000 Loss_G: 0.0156 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:02<00:00,  4.83s/it]
# [converting LR images to SR images] PSNR: 22.7495 dB SSIM: 0.7143: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.01it/s]
# [42/200] Loss_D: 1.0000 Loss_G: 0.0152 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:02<00:00,  4.80s/it]
# [converting LR images to SR images] PSNR: 23.4863 dB SSIM: 0.7072: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.01it/s]
# [43/200] Loss_D: 1.0000 Loss_G: 0.0154 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.73s/it]
# [converting LR images to SR images] PSNR: 22.7116 dB SSIM: 0.6913: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.02it/s]
# [44/200] Loss_D: 1.0000 Loss_G: 0.0158 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.73s/it]
# [converting LR images to SR images] PSNR: 22.9967 dB SSIM: 0.7000: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.06it/s]
# [45/200] Loss_D: 1.0000 Loss_G: 0.0154 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.68s/it]
# [converting LR images to SR images] PSNR: 22.8198 dB SSIM: 0.7065: 100%|██████████| 100/100 [01:01<00:00,  1.64it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.05it/s]
# [46/200] Loss_D: 1.0000 Loss_G: 0.0155 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:02<00:00,  4.79s/it]
# [converting LR images to SR images] PSNR: 23.9321 dB SSIM: 0.7160: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [47/200] Loss_D: 1.0000 Loss_G: 0.0158 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:02<00:00,  4.80s/it]
# [converting LR images to SR images] PSNR: 23.9095 dB SSIM: 0.7163: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.01it/s]
# [48/200] Loss_D: 1.0000 Loss_G: 0.0149 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.72s/it]
# [converting LR images to SR images] PSNR: 22.6095 dB SSIM: 0.7051: 100%|██████████| 100/100 [01:00<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.01it/s]
# [49/200] Loss_D: 1.0000 Loss_G: 0.0150 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.73s/it]
# [converting LR images to SR images] PSNR: 23.8289 dB SSIM: 0.7120: 100%|██████████| 100/100 [01:01<00:00,  1.63it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [50/200] Loss_D: 1.0000 Loss_G: 0.0143 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:02<00:00,  4.83s/it]
# [converting LR images to SR images] PSNR: 23.6932 dB SSIM: 0.7143: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [51/200] Loss_D: 1.0000 Loss_G: 0.0156 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:02<00:00,  4.81s/it]
# [converting LR images to SR images] PSNR: 22.8311 dB SSIM: 0.7091: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.02it/s]
# [52/200] Loss_D: 1.0000 Loss_G: 0.0157 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.72s/it]
# [converting LR images to SR images] PSNR: 23.6169 dB SSIM: 0.7217: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.01it/s]
# [53/200] Loss_D: 1.0000 Loss_G: 0.0147 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:02<00:00,  4.82s/it]
# [converting LR images to SR images] PSNR: 23.3205 dB SSIM: 0.7159: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.05it/s]
# [54/200] Loss_D: 1.0000 Loss_G: 0.0150 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.71s/it]
# [converting LR images to SR images] PSNR: 23.8484 dB SSIM: 0.7120: 100%|██████████| 100/100 [01:01<00:00,  1.64it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [55/200] Loss_D: 1.0000 Loss_G: 0.0155 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:02<00:00,  4.83s/it]
# [converting LR images to SR images] PSNR: 23.5995 dB SSIM: 0.6955: 100%|██████████| 100/100 [00:58<00:00,  1.71it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [56/200] Loss_D: 1.0000 Loss_G: 0.0153 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:03<00:00,  4.85s/it]
# [converting LR images to SR images] PSNR: 22.7537 dB SSIM: 0.7028: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:20<00:00,  1.00s/it]
# [57/200] Loss_D: 1.0000 Loss_G: 0.0141 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.75s/it]
# [converting LR images to SR images] PSNR: 23.3984 dB SSIM: 0.7225: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.01it/s]
# [58/200] Loss_D: 1.0000 Loss_G: 0.0146 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.73s/it]
# [converting LR images to SR images] PSNR: 24.1264 dB SSIM: 0.7235: 100%|██████████| 100/100 [01:01<00:00,  1.63it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.01it/s]
# [59/200] Loss_D: 1.0000 Loss_G: 0.0153 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.73s/it]
# [converting LR images to SR images] PSNR: 21.7866 dB SSIM: 0.7180: 100%|██████████| 100/100 [01:01<00:00,  1.62it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [60/200] Loss_D: 1.0000 Loss_G: 0.0147 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:03<00:00,  4.89s/it]
# [converting LR images to SR images] PSNR: 23.1760 dB SSIM: 0.7040: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.01it/s]
# [61/200] Loss_D: 1.0000 Loss_G: 0.0148 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:02<00:00,  4.83s/it]
# [converting LR images to SR images] PSNR: 23.0510 dB SSIM: 0.7076: 100%|██████████| 100/100 [01:01<00:00,  1.62it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.01it/s]
# [62/200] Loss_D: 1.0000 Loss_G: 0.0140 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.75s/it]
# [converting LR images to SR images] PSNR: 22.1284 dB SSIM: 0.7179: 100%|██████████| 100/100 [01:01<00:00,  1.62it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.05it/s]
# [63/200] Loss_D: 1.0000 Loss_G: 0.0148 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:02<00:00,  4.82s/it]
# [converting LR images to SR images] PSNR: 23.2262 dB SSIM: 0.7160: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.02it/s]
# [64/200] Loss_D: 1.0000 Loss_G: 0.0150 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:02<00:00,  4.78s/it]
# [converting LR images to SR images] PSNR: 23.8163 dB SSIM: 0.7175: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.01it/s]
# [65/200] Loss_D: 1.0000 Loss_G: 0.0143 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.74s/it]
# [converting LR images to SR images] PSNR: 23.2097 dB SSIM: 0.7225: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [66/200] Loss_D: 1.0000 Loss_G: 0.0149 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.76s/it]
# [converting LR images to SR images] PSNR: 23.5751 dB SSIM: 0.7219: 100%|██████████| 100/100 [01:01<00:00,  1.64it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.05it/s]
# [67/200] Loss_D: 1.0000 Loss_G: 0.0153 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.75s/it]
# [converting LR images to SR images] PSNR: 23.1550 dB SSIM: 0.7176: 100%|██████████| 100/100 [01:00<00:00,  1.64it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.04it/s]
# [68/200] Loss_D: 1.0000 Loss_G: 0.0157 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:03<00:00,  4.85s/it]
# [converting LR images to SR images] PSNR: 23.8500 dB SSIM: 0.7128: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:20<00:00,  1.01s/it]
# [69/200] Loss_D: 1.0000 Loss_G: 0.0137 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.71s/it]
# [converting LR images to SR images] PSNR: 24.1317 dB SSIM: 0.7282: 100%|██████████| 100/100 [01:01<00:00,  1.63it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.01it/s]
# [70/200] Loss_D: 1.0000 Loss_G: 0.0149 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.73s/it]
# [converting LR images to SR images] PSNR: 23.2614 dB SSIM: 0.7250: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [71/200] Loss_D: 1.0000 Loss_G: 0.0138 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:03<00:00,  4.87s/it]
# [converting LR images to SR images] PSNR: 23.8452 dB SSIM: 0.7020: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.01it/s]
# [72/200] Loss_D: 1.0000 Loss_G: 0.0153 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:03<00:00,  4.86s/it]
# [converting LR images to SR images] PSNR: 21.8093 dB SSIM: 0.7119: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:21<00:00,  1.06s/it]
# [73/200] Loss_D: 1.0000 Loss_G: 0.0146 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:03<00:00,  4.85s/it]
# [converting LR images to SR images] PSNR: 24.0255 dB SSIM: 0.7181: 100%|██████████| 100/100 [01:01<00:00,  1.63it/s]
# [saving training results]: 100%|██████████| 20/20 [00:20<00:00,  1.03s/it]
# [74/200] Loss_D: 1.0000 Loss_G: 0.0143 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:03<00:00,  4.90s/it]
# [converting LR images to SR images] PSNR: 23.6314 dB SSIM: 0.7255: 100%|██████████| 100/100 [01:00<00:00,  1.64it/s]
# [saving training results]: 100%|██████████| 20/20 [00:20<00:00,  1.02s/it]
# [75/200] Loss_D: 1.0000 Loss_G: 0.0140 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:02<00:00,  4.80s/it]
# [converting LR images to SR images] PSNR: 23.0512 dB SSIM: 0.7191: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:20<00:00,  1.00s/it]
# [76/200] Loss_D: 1.0000 Loss_G: 0.0141 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:02<00:00,  4.83s/it]
# [converting LR images to SR images] PSNR: 23.3377 dB SSIM: 0.7209: 100%|██████████| 100/100 [01:01<00:00,  1.61it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.01it/s]
# [77/200] Loss_D: 1.0000 Loss_G: 0.0140 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.77s/it]
# [converting LR images to SR images] PSNR: 23.9291 dB SSIM: 0.7167: 100%|██████████| 100/100 [01:01<00:00,  1.64it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.02it/s]
# [78/200] Loss_D: 1.0000 Loss_G: 0.0139 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:02<00:00,  4.82s/it]
# [converting LR images to SR images] PSNR: 23.7192 dB SSIM: 0.7179: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.00it/s]
# [79/200] Loss_D: 1.0000 Loss_G: 0.0145 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.70s/it]
# [converting LR images to SR images] PSNR: 23.0205 dB SSIM: 0.7210: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.02it/s]
# [80/200] Loss_D: 1.0000 Loss_G: 0.0143 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.72s/it]
# [converting LR images to SR images] PSNR: 22.1837 dB SSIM: 0.7197: 100%|██████████| 100/100 [01:01<00:00,  1.62it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.01it/s]
# [81/200] Loss_D: 1.0000 Loss_G: 0.0141 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.75s/it]
# [converting LR images to SR images] PSNR: 23.5848 dB SSIM: 0.7204: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.05it/s]
# [82/200] Loss_D: 1.0000 Loss_G: 0.0139 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:02<00:00,  4.77s/it]
# [converting LR images to SR images] PSNR: 23.9503 dB SSIM: 0.7246: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.02it/s]
# [83/200] Loss_D: 1.0000 Loss_G: 0.0138 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.69s/it]
# [converting LR images to SR images] PSNR: 24.2168 dB SSIM: 0.7183: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.01it/s]
# [84/200] Loss_D: 1.0000 Loss_G: 0.0137 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.66s/it]
# [converting LR images to SR images] PSNR: 24.1305 dB SSIM: 0.7247: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.04it/s]
# [85/200] Loss_D: 1.0000 Loss_G: 0.0138 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.70s/it]
# [converting LR images to SR images] PSNR: 23.6373 dB SSIM: 0.7170: 100%|██████████| 100/100 [01:01<00:00,  1.63it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.06it/s]
# [86/200] Loss_D: 1.0000 Loss_G: 0.0136 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.75s/it]
# [converting LR images to SR images] PSNR: 24.3874 dB SSIM: 0.7278: 100%|██████████| 100/100 [01:00<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.04it/s]
# [87/200] Loss_D: 1.0000 Loss_G: 0.0142 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:02<00:00,  4.78s/it]
# [converting LR images to SR images] PSNR: 22.1722 dB SSIM: 0.7257: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.01it/s]
# [88/200] Loss_D: 1.0000 Loss_G: 0.0140 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.74s/it]
# [converting LR images to SR images] PSNR: 24.0427 dB SSIM: 0.7225: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [89/200] Loss_D: 1.0000 Loss_G: 0.0135 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.60s/it]
# [converting LR images to SR images] PSNR: 24.1844 dB SSIM: 0.7293: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [90/200] Loss_D: 1.0000 Loss_G: 0.0138 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.59s/it]
# [converting LR images to SR images] PSNR: 23.8052 dB SSIM: 0.7190: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [91/200] Loss_D: 1.0000 Loss_G: 0.0141 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.62s/it]
# [converting LR images to SR images] PSNR: 23.4348 dB SSIM: 0.7228: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.05it/s]
# [92/200] Loss_D: 1.0000 Loss_G: 0.0140 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.72s/it]
# [converting LR images to SR images] PSNR: 23.8397 dB SSIM: 0.7264: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.06it/s]
# [93/200] Loss_D: 1.0000 Loss_G: 0.0142 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.66s/it]
# [converting LR images to SR images] PSNR: 23.6899 dB SSIM: 0.7115: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [94/200] Loss_D: 1.0000 Loss_G: 0.0130 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.61s/it]
# [converting LR images to SR images] PSNR: 23.9278 dB SSIM: 0.7259: 100%|██████████| 100/100 [01:00<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [95/200] Loss_D: 1.0000 Loss_G: 0.0131 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.63s/it]
# [converting LR images to SR images] PSNR: 24.2357 dB SSIM: 0.7319: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.04it/s]
# [96/200] Loss_D: 1.0000 Loss_G: 0.0129 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.64s/it]
# [converting LR images to SR images] PSNR: 23.1757 dB SSIM: 0.7261: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.06it/s]
# [97/200] Loss_D: 1.0000 Loss_G: 0.0140 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.60s/it]
# [converting LR images to SR images] PSNR: 24.1348 dB SSIM: 0.7245: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [98/200] Loss_D: 1.0000 Loss_G: 0.0135 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.59s/it]
# [converting LR images to SR images] PSNR: 22.9949 dB SSIM: 0.7242: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.08it/s]
# [99/200] Loss_D: 1.0000 Loss_G: 0.0135 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.59s/it]
# [converting LR images to SR images] PSNR: 23.9408 dB SSIM: 0.7222: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [100/200] Loss_D: 1.0000 Loss_G: 0.0132 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.63s/it]
# [converting LR images to SR images] PSNR: 24.2249 dB SSIM: 0.7300: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [101/200] Loss_D: 1.0000 Loss_G: 0.0137 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.67s/it]
# [converting LR images to SR images] PSNR: 23.9172 dB SSIM: 0.7270: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [102/200] Loss_D: 1.0000 Loss_G: 0.0129 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.70s/it]
# [converting LR images to SR images] PSNR: 23.9862 dB SSIM: 0.7299: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [103/200] Loss_D: 1.0000 Loss_G: 0.0134 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.66s/it]
# [converting LR images to SR images] PSNR: 24.0857 dB SSIM: 0.7223: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [104/200] Loss_D: 1.0000 Loss_G: 0.0126 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.61s/it]
# [converting LR images to SR images] PSNR: 24.0055 dB SSIM: 0.7289: 100%|██████████| 100/100 [00:59<00:00,  1.69it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [105/200] Loss_D: 1.0000 Loss_G: 0.0132 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.62s/it]
# [converting LR images to SR images] PSNR: 23.7734 dB SSIM: 0.7254: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.05it/s]
# [106/200] Loss_D: 1.0000 Loss_G: 0.0130 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.60s/it]
# [converting LR images to SR images] PSNR: 23.6031 dB SSIM: 0.7277: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.06it/s]
# [107/200] Loss_D: 1.0000 Loss_G: 0.0130 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.61s/it]
# [converting LR images to SR images] PSNR: 24.3659 dB SSIM: 0.7306: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [108/200] Loss_D: 1.0000 Loss_G: 0.0133 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.59s/it]
# [converting LR images to SR images] PSNR: 22.7919 dB SSIM: 0.7297: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.08it/s]
# [109/200] Loss_D: 1.0000 Loss_G: 0.0131 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.59s/it]
# [converting LR images to SR images] PSNR: 23.8778 dB SSIM: 0.7250: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.06it/s]
# [110/200] Loss_D: 1.0000 Loss_G: 0.0138 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.62s/it]
# [converting LR images to SR images] PSNR: 23.9556 dB SSIM: 0.7333: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.06it/s]
# [111/200] Loss_D: 1.0000 Loss_G: 0.0130 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.68s/it]
# [converting LR images to SR images] PSNR: 24.3379 dB SSIM: 0.7340: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.06it/s]
# [112/200] Loss_D: 1.0000 Loss_G: 0.0132 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.68s/it]
# [converting LR images to SR images] PSNR: 23.8449 dB SSIM: 0.7256: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.04it/s]
# [113/200] Loss_D: 1.0000 Loss_G: 0.0134 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.65s/it]
# [converting LR images to SR images] PSNR: 24.2216 dB SSIM: 0.7353: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.04it/s]
# [114/200] Loss_D: 1.0000 Loss_G: 0.0130 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.61s/it]
# [converting LR images to SR images] PSNR: 23.9989 dB SSIM: 0.7281: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.04it/s]
# [115/200] Loss_D: 1.0000 Loss_G: 0.0131 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.62s/it]
# [converting LR images to SR images] PSNR: 24.4503 dB SSIM: 0.7271: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [116/200] Loss_D: 1.0000 Loss_G: 0.0132 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.61s/it]
# [converting LR images to SR images] PSNR: 23.2190 dB SSIM: 0.7302: 100%|██████████| 100/100 [00:58<00:00,  1.70it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [117/200] Loss_D: 1.0000 Loss_G: 0.0130 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.58s/it]
# [converting LR images to SR images] PSNR: 23.8880 dB SSIM: 0.7318: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.04it/s]
# [118/200] Loss_D: 1.0000 Loss_G: 0.0133 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.58s/it]
# [converting LR images to SR images] PSNR: 24.1060 dB SSIM: 0.7312: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.05it/s]
# [119/200] Loss_D: 1.0000 Loss_G: 0.0125 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.60s/it]
# [converting LR images to SR images] PSNR: 24.3067 dB SSIM: 0.7330: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.05it/s]
# [120/200] Loss_D: 1.0000 Loss_G: 0.0135 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:02<00:00,  4.85s/it]
# [converting LR images to SR images] PSNR: 24.3343 dB SSIM: 0.7358: 100%|██████████| 100/100 [01:00<00:00,  1.64it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [121/200] Loss_D: 1.0000 Loss_G: 0.0130 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.68s/it]
# [converting LR images to SR images] PSNR: 23.2735 dB SSIM: 0.7300: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.04it/s]
# [122/200] Loss_D: 1.0000 Loss_G: 0.0131 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.67s/it]
# [converting LR images to SR images] PSNR: 23.7311 dB SSIM: 0.7222: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [123/200] Loss_D: 1.0000 Loss_G: 0.0135 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.61s/it]
# [converting LR images to SR images] PSNR: 23.6441 dB SSIM: 0.7214: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [124/200] Loss_D: 1.0000 Loss_G: 0.0131 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.61s/it]
# [converting LR images to SR images] PSNR: 23.8798 dB SSIM: 0.7332: 100%|██████████| 100/100 [00:59<00:00,  1.69it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.04it/s]
# [125/200] Loss_D: 1.0000 Loss_G: 0.0132 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.62s/it]
# [converting LR images to SR images] PSNR: 22.7293 dB SSIM: 0.7149: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.05it/s]
# [126/200] Loss_D: 1.0000 Loss_G: 0.0133 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.64s/it]
# [converting LR images to SR images] PSNR: 23.4894 dB SSIM: 0.7279: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.08it/s]
# [127/200] Loss_D: 1.0000 Loss_G: 0.0133 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.59s/it]
# [converting LR images to SR images] PSNR: 23.8023 dB SSIM: 0.7334: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [128/200] Loss_D: 1.0000 Loss_G: 0.0130 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.59s/it]
# [converting LR images to SR images] PSNR: 24.1371 dB SSIM: 0.7343: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [129/200] Loss_D: 1.0000 Loss_G: 0.0127 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.59s/it]
# [converting LR images to SR images] PSNR: 23.3697 dB SSIM: 0.7310: 100%|██████████| 100/100 [01:01<00:00,  1.63it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [130/200] Loss_D: 1.0000 Loss_G: 0.0131 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.69s/it]
# [converting LR images to SR images] PSNR: 23.3468 dB SSIM: 0.7232: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [131/200] Loss_D: 1.0000 Loss_G: 0.0133 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.70s/it]
# [converting LR images to SR images] PSNR: 18.4382 dB SSIM: 0.6822: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.05it/s]
# [132/200] Loss_D: 1.0000 Loss_G: 0.0128 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.65s/it]
# [converting LR images to SR images] PSNR: 9.9938 dB SSIM: 0.5717: 100%|██████████| 100/100 [01:00<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [133/200] Loss_D: 1.0000 Loss_G: 0.0157 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.63s/it]
# [converting LR images to SR images] PSNR: 22.5897 dB SSIM: 0.7102: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [134/200] Loss_D: 1.0000 Loss_G: 0.0145 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.63s/it]
# [converting LR images to SR images] PSNR: 23.1003 dB SSIM: 0.7245: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.04it/s]
# [135/200] Loss_D: 1.0000 Loss_G: 0.0144 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.62s/it]
# [converting LR images to SR images] PSNR: 23.5726 dB SSIM: 0.7040: 100%|██████████| 100/100 [01:00<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.05it/s]
# [136/200] Loss_D: 1.0000 Loss_G: 0.0141 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.65s/it]
# [converting LR images to SR images] PSNR: 22.3089 dB SSIM: 0.7190: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [137/200] Loss_D: 1.0000 Loss_G: 0.0139 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.64s/it]
# [converting LR images to SR images] PSNR: 24.0078 dB SSIM: 0.7082: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [138/200] Loss_D: 1.0000 Loss_G: 0.0124 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.62s/it]
# [converting LR images to SR images] PSNR: 23.9865 dB SSIM: 0.7298: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.06it/s]
# [139/200] Loss_D: 1.0000 Loss_G: 0.0135 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.64s/it]
# [converting LR images to SR images] PSNR: 24.0497 dB SSIM: 0.7271: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [140/200] Loss_D: 1.0000 Loss_G: 0.0132 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.68s/it]
# [converting LR images to SR images] PSNR: 24.2266 dB SSIM: 0.7330: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.05it/s]
# [141/200] Loss_D: 1.0000 Loss_G: 0.0125 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.66s/it]
# [converting LR images to SR images] PSNR: 23.7270 dB SSIM: 0.7295: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.04it/s]
# [142/200] Loss_D: 1.0000 Loss_G: 0.0127 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.67s/it]
# [converting LR images to SR images] PSNR: 23.8751 dB SSIM: 0.7297: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.02it/s]
# [143/200] Loss_D: 1.0000 Loss_G: 0.0130 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.61s/it]
# [converting LR images to SR images] PSNR: 23.6770 dB SSIM: 0.7127: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [144/200] Loss_D: 1.0000 Loss_G: 0.0125 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.60s/it]
# [converting LR images to SR images] PSNR: 24.0278 dB SSIM: 0.7328: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.05it/s]
# [145/200] Loss_D: 1.0000 Loss_G: 0.0131 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.60s/it]
# [converting LR images to SR images] PSNR: 24.0267 dB SSIM: 0.7284: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.06it/s]
# [146/200] Loss_D: 1.0000 Loss_G: 0.0128 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.58s/it]
# [converting LR images to SR images] PSNR: 24.1249 dB SSIM: 0.7350: 100%|██████████| 100/100 [01:00<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [147/200] Loss_D: 1.0000 Loss_G: 0.0127 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.58s/it]
# [converting LR images to SR images] PSNR: 24.1547 dB SSIM: 0.7318: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [148/200] Loss_D: 1.0000 Loss_G: 0.0127 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.59s/it]
# [converting LR images to SR images] PSNR: 24.3297 dB SSIM: 0.7290: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [149/200] Loss_D: 1.0000 Loss_G: 0.0139 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.67s/it]
# [converting LR images to SR images] PSNR: 24.1196 dB SSIM: 0.7330: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.06it/s]
# [150/200] Loss_D: 1.0000 Loss_G: 0.0128 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.69s/it]
# [converting LR images to SR images] PSNR: 24.4271 dB SSIM: 0.7322: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.02it/s]
# [151/200] Loss_D: 1.0000 Loss_G: 0.0121 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.63s/it]
# [converting LR images to SR images] PSNR: 24.4625 dB SSIM: 0.7307: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.01it/s]
# [152/200] Loss_D: 1.0000 Loss_G: 0.0129 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.59s/it]
# [converting LR images to SR images] PSNR: 24.2009 dB SSIM: 0.7219: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [153/200] Loss_D: 1.0000 Loss_G: 0.0128 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.65s/it]
# [converting LR images to SR images] PSNR: 22.8778 dB SSIM: 0.7298: 100%|██████████| 100/100 [01:00<00:00,  1.66it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.06it/s]
# [154/200] Loss_D: 1.0000 Loss_G: 0.0139 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.64s/it]
# [converting LR images to SR images] PSNR: 23.2921 dB SSIM: 0.7342: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.08it/s]
# [155/200] Loss_D: 1.0000 Loss_G: 0.0130 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.58s/it]
# [converting LR images to SR images] PSNR: 23.4925 dB SSIM: 0.7356: 100%|██████████| 100/100 [01:01<00:00,  1.63it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.08it/s]
# [156/200] Loss_D: 1.0000 Loss_G: 0.0127 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.63s/it]
# [converting LR images to SR images] PSNR: 24.5664 dB SSIM: 0.7352: 100%|██████████| 100/100 [01:00<00:00,  1.65it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.07it/s]
# [157/200] Loss_D: 1.0000 Loss_G: 0.0125 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:01<00:00,  4.71s/it]
# [converting LR images to SR images] PSNR: 24.4599 dB SSIM: 0.7370: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:18<00:00,  1.05it/s]
# [158/200] Loss_D: 1.0000 Loss_G: 0.0124 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [01:00<00:00,  4.64s/it]
# [converting LR images to SR images] PSNR: 24.4776 dB SSIM: 0.7348: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.04it/s]
# [159/200] Loss_D: 1.0000 Loss_G: 0.0122 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.59s/it]
# [converting LR images to SR images] PSNR: 23.1128 dB SSIM: 0.7367: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [160/200] Loss_D: 1.0000 Loss_G: 0.0128 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.60s/it]
# [converting LR images to SR images] PSNR: 23.9163 dB SSIM: 0.7298: 100%|██████████| 100/100 [00:59<00:00,  1.67it/s]
# [saving training results]: 100%|██████████| 20/20 [00:19<00:00,  1.03it/s]
# [161/200] Loss_D: 1.0000 Loss_G: 0.0130 D(x): 0.0000 D(G(z)): 0.0000: 100%|██████████| 13/13 [00:59<00:00,  4.61s/it]
# [converting LR images to SR images] PSNR: 23.2845 dB SSIM: 0.7288: 100%|██████████| 100/100 [00:59<00:00,  1.68it/s]
# [saving training results]:   5%|▌         | 1/20 [00:01<00:27,  1.43s/it]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     642     try:
# --> 643         fh = fp.fileno()
#     644         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-7a02632fd570> in <cell line: 0>()
#      88         for image in val_save_bar:
#      89             image = utils.make_grid(image, nrow=3, padding=5)
# ---> 90             utils.save_image(image, out_path + 'epoch_%d_index_%d.png' % (epoch, index), padding=5)
#      91             index += 1
#      92
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/torchvision/utils.py in save_image(tensor, fp, format, **kwargs)
#     149     ndarr = grid.mul(255).add_(0.5).clamp_(0, 255).permute(1, 2, 0).to("cpu", torch.uint8).numpy()
#     150     im = Image.fromarray(ndarr)
# --> 151     im.save(fp, format=format)
#     152
#     153
#
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    2579
#    2580         try:
# -> 2581             save_handler(self, fp, filename)
#    2582         except Exception:
#    2583             if open_fp:
#
# /usr/local/lib/python3.11/dist-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk, save_all)
#    1490         )
#    1491     if single_im:
# -> 1492         ImageFile._save(
#    1493             single_im,
#    1494             cast(IO[bytes], _idat(fp, chunk)),
#
# /usr/local/lib/python3.11/dist-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     645         _encode_tile(im, fp, tile, bufsize, fh)
#     646     except (AttributeError, io.UnsupportedOperation) as exc:
# --> 647         _encode_tile(im, fp, tile, bufsize, None, exc)
#     648     if hasattr(fp, "flush"):
#     649         fp.flush()
#
# /usr/local/lib/python3.11/dist-packages/PIL/ImageFile.py in _encode_tile(im, fp, tile, bufsize, fh, exc)
#     671                     # compress to Python file-compatible object
#     672                     while True:
# --> 673                         errcode, data = encoder.encode(bufsize)[1:]
#     674                         fp.write(data)
#     675                         if errcode:
#
# KeyboardInterrupt:

# %%
# import shutil

# shutil.make_archive('/content/epochs', 'zip', '/content/epochs')
# Out:
# '/content/epochs.zip'
